# %% [markdown]
# # Introduction
# <p>The dataset is from <a href='https://www.kaggle.com/andrewmvd/data-analyst-jobs'> <span> Kaggle</span> </a>.</p>
# <p>There are three questions of interest:</p>
# <p>1.Find the best jobs by salary and company rating</p>
# <p>2.Explore skills required in job descriptions</p>
# <p>3.Predict salary based on industry, location, company revenue</p>

# %% [markdown]
# Firstly, read in the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
# %matplotlib inline

# %% [markdown]
# step 1: load and clean data

# %%
# load dataset
df = pd.read_csv('./Dataset/DataAnalyst.csv',index_col=0)

df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
# 1)get columns and rows of dataset
print(df.shape)  # rows: 2253 columns: 15

# 2)check null value in columns
df.info() # not exists NaN in all columns
# Out:
# (2253, 15)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 281.6+ KB

# %%
# 3)check abnormal value in columns one by one
# df.columns[0]]
print(df['Job Title'].dtype)
df['Job Title'].value_counts() # no abnormal value
# Out:
# object
# Data Analyst                                           405
# Senior Data Analyst                                     90
# Junior Data Analyst                                     30
# Business Data Analyst                                   28
# Sr. Data Analyst                                        21
#                                                       ...
# Senior Business Intelligence & Data Science Analyst      1
# Product Analyst - Data                                   1
# Senior Data Analyst and Applied Scientist                1
# Data Reporting Analyst, BI                               1
# Sr Data Management Analyst                               1
# Name: Job Title, Length: 1272, dtype: int64

# %%
# df.columns[1]
print(df['Salary Estimate'].dtype)
df['Salary Estimate'].value_counts(dropna=False) # need to repace -1 into np.nan
df['Salary Estimate'] = df[df.columns[1]].replace('-1',np.nan)
df['Salary Estimate'].value_counts(dropna=False)
df['Salary Estimate'].isnull().mean()  # only exists 1 missing value, so I decide to drop this data
df[df['Salary Estimate'].isnull()]
df.drop(index=2149,inplace=True)
# Out:
# object

# %%
s = df["Salary Estimate"].str.split(" ",n=1,expand=True)
sr = s[0].str.split('-',expand=True,n=1)
df['lower_salary'] = sr[0].str.replace('$','')
df['lower_salary'] = df['lower_salary'].str.replace('K','000')
df['upper_salary'] = sr[1].str.replace('$','')
df['upper_salary'] = df['upper_salary'].str.replace('K','000')


df['upper_salary'] = df['upper_salary'].astype('int')
df['lower_salary'] = df['lower_salary'].astype('int')
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\r\n\r\nProvides analytical and techni...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4  ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
#
#                                 Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\r\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\r\n3.8  New York, NY  New York, NY
# 2                         Squarespace\r\n3.4  New York, NY  New York, NY
# 3                            Celerity\r\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\r\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply  lower_salary  \
# 0  $100 to $500 million (USD)          -1       True         37000
# 1      $2 to $5 billion (USD)          -1         -1         37000
# 2    Unknown / Non-Applicable     GoDaddy         -1         37000
# 3   $50 to $100 million (USD)          -1         -1         37000
# 4  $100 to $500 million (USD)  DraftKings       True         37000
#
#    upper_salary
# 0         66000
# 1         66000
# 2         66000
# 3         66000
# 4         66000

# %%
# df.columns[2]
print(df['Job Description'].dtype)
df['Job Description'].value_counts(dropna=False)
df['Job Description'].isnull().mean()
# Out:
# object
# 0.0

# %%
# df.columns[3]
print(df['Rating'].dtype)
df['Rating'].value_counts(dropna=False)
df['Rating'] = df[df.columns[3]].replace(-1,np.nan)
df['Rating'].isnull().mean()
df['Rating'].value_counts(dropna=False)
df[df['Rating'].isnull()]   # delay cleaning
# Out:
# float64
#                                               Job Title  \
# 11                                         Data Analyst
# 21                                 Data Science Analyst
# 34                                 Data Analyst (Games)
# 36                                Data Business Analyst
# 40                     Business Analyst, Data Platforms
# ...                                                 ...
# 2200                                       Data Analyst
# 2202                             Financial Data Analyst
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 11     $37K-$66K (Glassdoor est.)
# 21     $37K-$66K (Glassdoor est.)
# 34     $46K-$87K (Glassdoor est.)
# 36     $46K-$87K (Glassdoor est.)
# 40     $46K-$87K (Glassdoor est.)
# ...                           ...
# 2200   $49K-$91K (Glassdoor est.)
# 2202   $49K-$91K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 21    Job Description\r\nOur client, a music streami...     NaN
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 36    At Clear Street, we are disrupting the institu...     NaN
# 40    Company Description\r\n\r\nPinto is building t...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                      Company Name        Location  \
# 11                                       BulbHead   Fairfield, NJ
# 21                          MUSIC & Entertainment    New York, NY
# 34                                       Carry1st    New York, NY
# 36                                   Clear Street    New York, NY
# 40                                          Pinto    New York, NY
# ...                                           ...             ...
# 2200    TechAspect Solutions, Inc. dba TA Digital  Centennial, CO
# 2202  Black Knight Financial Technology Solutions      Denver, CO
# 2239                                  Amyx, Iinc.      Aurora, CO
# 2246                                     Spiceorb      Denver, CO
# 2250                                     Spiceorb      Denver, CO
#
#             Headquarters                 Size  Founded  Type of ownership  \
# 11                    -1    1 to 50 employees       -1  Company - Private
# 21    Marina del Rey, CA              Unknown       -1   Company - Public
# 34                    -1                   -1       -1                 -1
# 36          New York, NY  51 to 200 employees     2018   Company - Public
# 40          New York, NY    1 to 50 employees       -1  Company - Private
# ...                  ...                  ...      ...                ...
# 2200                  -1                   -1       -1                 -1
# 2202                  -1                   -1       -1                 -1
# 2239                  -1                   -1       -1                 -1
# 2246                  -1                   -1       -1                 -1
# 2250                  -1                   -1       -1                 -1
#
#      Industry Sector                   Revenue Competitors Easy Apply
# 11         -1     -1  Unknown / Non-Applicable          -1         -1
# 21         -1     -1  Unknown / Non-Applicable          -1         -1
# 34         -1     -1                        -1          -1         -1
# 36         -1     -1    $1 to $5 million (USD)          -1         -1
# 40         -1     -1  Unknown / Non-Applicable          -1         -1
# ...       ...    ...                       ...         ...        ...
# 2200       -1     -1                        -1          -1         -1
# 2202       -1     -1                        -1          -1         -1
# 2239       -1     -1                        -1          -1         -1
# 2246       -1     -1                        -1          -1         -1
# 2250       -1     -1                        -1          -1         -1
#
# [272 rows x 15 columns]

# %%
# df.columns[4]
print(df['Company Name'].dtype)
df['Company Name'].value_counts(dropna=False)
df['Company Name'].isnull().mean()
df[df['Company Name'].isnull()]
df.drop(index=1860,inplace=True)
# Out:
# object

# %%
# df.columns[5]
print(df['Location'].dtype)
df['Location'].value_counts(dropna=False)
df['Location'].isnull().mean()
# Out:
# object
# 0.0

# %%
# df.columns[6]
print(df['Headquarters'].dtype)
df['Headquarters'].value_counts(dropna=False)
df['Headquarters'] = df[df.columns[6]].replace('-1',np.nan)
df['Headquarters'].isnull().mean()
df[df['Headquarters'].isnull()] # delay cleaning
# Out:
# object
#                                               Job Title  \
# 11                                         Data Analyst
# 34                                 Data Analyst (Games)
# 55                               Data Reporting Analyst
# 68                                 Data Science Analyst
# 90                                         Data Analyst
# ...                                                 ...
# 2200                                       Data Analyst
# 2202                             Financial Data Analyst
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 11     $37K-$66K (Glassdoor est.)
# 34     $46K-$87K (Glassdoor est.)
# 55     $46K-$87K (Glassdoor est.)
# 68     $51K-$88K (Glassdoor est.)
# 90     $51K-$87K (Glassdoor est.)
# ...                           ...
# 2200   $49K-$91K (Glassdoor est.)
# 2202   $49K-$91K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name        Location  \
# 11                                             BulbHead   Fairfield, NJ
# 34                                             Carry1st    New York, NY
# 55                                       NADAP NYS INC.    New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)    New York, NY
# 90                           NYU Langone Medical Center    New York, NY
# ...                                                 ...             ...
# 2200          TechAspect Solutions, Inc. dba TA Digital  Centennial, CO
# 2202        Black Knight Financial Technology Solutions      Denver, CO
# 2239                                        Amyx, Iinc.      Aurora, CO
# 2246                                           Spiceorb      Denver, CO
# 2250                                           Spiceorb      Denver, CO
#
#      Headquarters               Size  Founded  Type of ownership Industry  \
# 11            NaN  1 to 50 employees       -1  Company - Private       -1
# 34            NaN                 -1       -1                 -1       -1
# 55            NaN                 -1       -1                 -1       -1
# 68            NaN                 -1       -1                 -1       -1
# 90            NaN                 -1       -1                 -1       -1
# ...           ...                ...      ...                ...      ...
# 2200          NaN                 -1       -1                 -1       -1
# 2202          NaN                 -1       -1                 -1       -1
# 2239          NaN                 -1       -1                 -1       -1
# 2246          NaN                 -1       -1                 -1       -1
# 2250          NaN                 -1       -1                 -1       -1
#
#      Sector                   Revenue Competitors Easy Apply
# 11       -1  Unknown / Non-Applicable          -1         -1
# 34       -1                        -1          -1         -1
# 55       -1                        -1          -1         -1
# 68       -1                        -1          -1         -1
# 90       -1                        -1          -1         -1
# ...     ...                       ...         ...        ...
# 2200     -1                        -1          -1         -1
# 2202     -1                        -1          -1         -1
# 2239     -1                        -1          -1         -1
# 2246     -1                        -1          -1         -1
# 2250     -1                        -1          -1         -1
#
# [171 rows x 15 columns]

# %%
# df.columns[7]
print(df['Size'].dtype)
df['Size'].value_counts(dropna=False)
df['Size'] = df[df.columns[7]].replace('-1',np.nan)
df['Size'].isnull().mean()
df[df['Size'].isnull()] # delay cleaning
# Out:
# object
#                                               Job Title  \
# 34                                 Data Analyst (Games)
# 55                               Data Reporting Analyst
# 68                                 Data Science Analyst
# 90                                         Data Analyst
# 109                                        Data Analyst
# ...                                                 ...
# 2200                                       Data Analyst
# 2202                             Financial Data Analyst
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 34     $46K-$87K (Glassdoor est.)
# 55     $46K-$87K (Glassdoor est.)
# 68     $51K-$88K (Glassdoor est.)
# 90     $51K-$87K (Glassdoor est.)
# 109    $51K-$87K (Glassdoor est.)
# ...                           ...
# 2200   $49K-$91K (Glassdoor est.)
# 2202   $49K-$91K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# 109   Data Analyst\r\n\r\nJersey City, NJ\r\n\r\n12+...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name         Location  \
# 34                                             Carry1st     New York, NY
# 55                                       NADAP NYS INC.     New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                           NYU Langone Medical Center     New York, NY
# 109                                Vertex Intel Systems  Jersey City, NJ
# ...                                                 ...              ...
# 2200          TechAspect Solutions, Inc. dba TA Digital   Centennial, CO
# 2202        Black Knight Financial Technology Solutions       Denver, CO
# 2239                                        Amyx, Iinc.       Aurora, CO
# 2246                                           Spiceorb       Denver, CO
# 2250                                           Spiceorb       Denver, CO
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 34            NaN  NaN       -1                -1       -1     -1      -1
# 55            NaN  NaN       -1                -1       -1     -1      -1
# 68            NaN  NaN       -1                -1       -1     -1      -1
# 90            NaN  NaN       -1                -1       -1     -1      -1
# 109           NaN  NaN       -1                -1       -1     -1      -1
# ...           ...  ...      ...               ...      ...    ...     ...
# 2200          NaN  NaN       -1                -1       -1     -1      -1
# 2202          NaN  NaN       -1                -1       -1     -1      -1
# 2239          NaN  NaN       -1                -1       -1     -1      -1
# 2246          NaN  NaN       -1                -1       -1     -1      -1
# 2250          NaN  NaN       -1                -1       -1     -1      -1
#
#      Competitors Easy Apply
# 34            -1         -1
# 55            -1         -1
# 68            -1         -1
# 90            -1         -1
# 109           -1         -1
# ...          ...        ...
# 2200          -1         -1
# 2202          -1         -1
# 2239          -1         -1
# 2246          -1         -1
# 2250          -1         -1
#
# [162 rows x 15 columns]

# %%
# df.columns[8]
print(df['Founded'].dtype)
df['Founded'].value_counts(dropna=False)
df['Founded'] = df[df.columns[8]].replace(-1,np.nan)
df['Founded'].value_counts(dropna=False)
df['Founded'].isnull().mean()
df[df['Founded'].isnull()] # delay cleaning
# Out:
# int64
#                                               Job Title  \
# 11                                         Data Analyst
# 15                          Sustainability Data Analyst
# 21                                 Data Science Analyst
# 23                                         Data Analyst
# 24                       Entry Level / Jr. Data Analyst
# ...                                                 ...
# 2244                          Data Security Analyst, Sr
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2247  Marketing/Communications - Data Analyst-Marketing
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 11     $37K-$66K (Glassdoor est.)
# 15     $37K-$66K (Glassdoor est.)
# 21     $37K-$66K (Glassdoor est.)
# 23     $37K-$66K (Glassdoor est.)
# 24     $37K-$66K (Glassdoor est.)
# ...                           ...
# 2244  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2247  $78K-$104K (Glassdoor est.)
# 2248  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 15    Job Description\r\nRole Description\r\n\r\nSus...     3.6
# 21    Job Description\r\nOur client, a music streami...     NaN
# 23    Haven Life is an insurtech innovator at MassMu...     3.5
# 24    Dash Technologies is an industry leading softw...     3.8
# ...                                                 ...     ...
# 2244  Contract Duration: 9 Months\r\n\r\nLocation: D...     2.5
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2247  Job Description\r\nJob Title: Marketing/Commun...     4.1
# 2248  Maintains systems to protect data from unautho...     2.5
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                            Company Name        Location        Headquarters  \
# 11                             BulbHead   Fairfield, NJ                 NaN
# 15           CodeGreen Solutions\r\n3.6    New York, NY        New York, NY
# 21                MUSIC & Entertainment    New York, NY  Marina del Rey, CA
# 23                       Andiamo\r\n3.5    New York, NY          Warren, MI
# 24         Dash Technologies Inc\r\n3.8    New York, NY        Columbus, OH
# ...                                 ...             ...                 ...
# 2244               Avacend, Inc.\r\n2.5      Denver, CO      Alpharetta, GA
# 2246                           Spiceorb      Denver, CO                 NaN
# 2247  APN Software Services Inc.\r\n4.1  Broomfield, CO          Newark, CA
# 2248               Avacend, Inc.\r\n2.5      Denver, CO      Alpharetta, GA
# 2250                           Spiceorb      Denver, CO                 NaN
#
#                       Size  Founded  Type of ownership  \
# 11       1 to 50 employees      NaN  Company - Private
# 15       1 to 50 employees      NaN  Company - Private
# 21                 Unknown      NaN   Company - Public
# 23    201 to 500 employees      NaN  Company - Private
# 24       1 to 50 employees      NaN            Unknown
# ...                    ...      ...                ...
# 2244   51 to 200 employees      NaN  Company - Private
# 2246                   NaN      NaN                 -1
# 2247   51 to 200 employees      NaN  Company - Private
# 2248   51 to 200 employees      NaN  Company - Private
# 2250                   NaN      NaN                 -1
#
#                            Industry                             Sector  \
# 11                               -1                                 -1
# 15    Building & Personnel Services                  Business Services
# 21                               -1                                 -1
# 23               Casual Restaurants  Restaurants, Bars & Food Services
# 24                               -1                                 -1
# ...                             ...                                ...
# 2244         Staffing & Outsourcing                  Business Services
# 2246                             -1                                 -1
# 2247   Computer Hardware & Software             Information Technology
# 2248         Staffing & Outsourcing                  Business Services
# 2250                             -1                                 -1
#
#                        Revenue Competitors Easy Apply
# 11    Unknown / Non-Applicable          -1         -1
# 15    Unknown / Non-Applicable          -1         -1
# 21    Unknown / Non-Applicable          -1         -1
# 23      $1 to $5 million (USD)          -1         -1
# 24    Unknown / Non-Applicable          -1         -1
# ...                        ...         ...        ...
# 2244  Unknown / Non-Applicable          -1         -1
# 2246                        -1          -1         -1
# 2247  $25 to $50 million (USD)          -1         -1
# 2248  Unknown / Non-Applicable          -1         -1
# 2250                        -1          -1         -1
#
# [659 rows x 15 columns]

# %%
# df.columns[9]
print(df['Type of ownership'].dtype)
df['Type of ownership'].value_counts(dropna=False)
df['Type of ownership'] = df[df.columns[9]].replace('-1',np.nan)
df['Type of ownership'].isnull().mean()
df[df['Type of ownership'].isnull()] # delay cleaning
# Out:
# object
#                                               Job Title  \
# 34                                 Data Analyst (Games)
# 55                               Data Reporting Analyst
# 68                                 Data Science Analyst
# 90                                         Data Analyst
# 109                                        Data Analyst
# ...                                                 ...
# 2200                                       Data Analyst
# 2202                             Financial Data Analyst
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 34     $46K-$87K (Glassdoor est.)
# 55     $46K-$87K (Glassdoor est.)
# 68     $51K-$88K (Glassdoor est.)
# 90     $51K-$87K (Glassdoor est.)
# 109    $51K-$87K (Glassdoor est.)
# ...                           ...
# 2200   $49K-$91K (Glassdoor est.)
# 2202   $49K-$91K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# 109   Data Analyst\r\n\r\nJersey City, NJ\r\n\r\n12+...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name         Location  \
# 34                                             Carry1st     New York, NY
# 55                                       NADAP NYS INC.     New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                           NYU Langone Medical Center     New York, NY
# 109                                Vertex Intel Systems  Jersey City, NJ
# ...                                                 ...              ...
# 2200          TechAspect Solutions, Inc. dba TA Digital   Centennial, CO
# 2202        Black Knight Financial Technology Solutions       Denver, CO
# 2239                                        Amyx, Iinc.       Aurora, CO
# 2246                                           Spiceorb       Denver, CO
# 2250                                           Spiceorb       Denver, CO
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 34            NaN  NaN      NaN               NaN       -1     -1      -1
# 55            NaN  NaN      NaN               NaN       -1     -1      -1
# 68            NaN  NaN      NaN               NaN       -1     -1      -1
# 90            NaN  NaN      NaN               NaN       -1     -1      -1
# 109           NaN  NaN      NaN               NaN       -1     -1      -1
# ...           ...  ...      ...               ...      ...    ...     ...
# 2200          NaN  NaN      NaN               NaN       -1     -1      -1
# 2202          NaN  NaN      NaN               NaN       -1     -1      -1
# 2239          NaN  NaN      NaN               NaN       -1     -1      -1
# 2246          NaN  NaN      NaN               NaN       -1     -1      -1
# 2250          NaN  NaN      NaN               NaN       -1     -1      -1
#
#      Competitors Easy Apply
# 34            -1         -1
# 55            -1         -1
# 68            -1         -1
# 90            -1         -1
# 109           -1         -1
# ...          ...        ...
# 2200          -1         -1
# 2202          -1         -1
# 2239          -1         -1
# 2246          -1         -1
# 2250          -1         -1
#
# [162 rows x 15 columns]

# %%
# df.columns[10]
print(df['Industry'].dtype)
df['Industry'].value_counts(dropna=False)
df['Industry'] = df[df.columns[10]].replace('-1',np.nan)
df['Industry'].isnull().mean()
df[df['Industry'].isnull()]  # delay cleaning
# Out:
# object
#                                               Job Title  \
# 11                                         Data Analyst
# 21                                 Data Science Analyst
# 24                       Entry Level / Jr. Data Analyst
# 32                                         Data Analyst
# 34                                 Data Analyst (Games)
# ...                                                 ...
# 2220  MDG Functional Data Analyst-Greenwood Village, CO
# 2234   Data Analyst 3, Customer Experience - Centennial
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 11     $37K-$66K (Glassdoor est.)
# 21     $37K-$66K (Glassdoor est.)
# 24     $37K-$66K (Glassdoor est.)
# 32     $46K-$87K (Glassdoor est.)
# 34     $46K-$87K (Glassdoor est.)
# ...                           ...
# 2220  $57K-$100K (Glassdoor est.)
# 2234  $57K-$100K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 21    Job Description\r\nOur client, a music streami...     NaN
# 24    Dash Technologies is an industry leading softw...     3.8
# 32    Job Description:\r\nLegal experience is requir...     3.5
# 34    Carry1st is the leading mobile game publisher ...     NaN
# ...                                                 ...     ...
# 2220  MDG Functional Data Analyst\r\nLocation: Green...     5.0
# 2234  Business Unit: Summary Responsible for working...     3.6
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                       Company Name                         Location  \
# 11                        BulbHead                    Fairfield, NJ
# 21           MUSIC & Entertainment                     New York, NY
# 24    Dash Technologies Inc\r\n3.8                     New York, NY
# 32                   Pozent\r\n3.5                     New York, NY
# 34                        Carry1st                     New York, NY
# ...                            ...                              ...
# 2220        Georgia IT Inc.\r\n5.0  Greenwood Village, Arapahoe, CO
# 2234                Comcast\r\n3.6                    Englewood, CO
# 2239                   Amyx, Iinc.                       Aurora, CO
# 2246                      Spiceorb                       Denver, CO
# 2250                      Spiceorb                       Denver, CO
#
#             Headquarters               Size  Founded  Type of ownership  \
# 11                   NaN  1 to 50 employees      NaN  Company - Private
# 21    Marina del Rey, CA            Unknown      NaN   Company - Public
# 24          Columbus, OH  1 to 50 employees      NaN            Unknown
# 32        Piscataway, NJ  1 to 50 employees      NaN           Contract
# 34                   NaN                NaN      NaN                NaN
# ...                  ...                ...      ...                ...
# 2220      Alpharetta, GA  1 to 50 employees      NaN  Company - Private
# 2234    Philadelphia, PA   10000+ employees   1963.0   Company - Public
# 2239                 NaN                NaN      NaN                NaN
# 2246                 NaN                NaN      NaN                NaN
# 2250                 NaN                NaN      NaN                NaN
#
#      Industry Sector                     Revenue    Competitors  Easy Apply
# 11        NaN    NaN    Unknown / Non-Applicable            NaN           0
# 21        NaN    NaN    Unknown / Non-Applicable            NaN           0
# 24        NaN    NaN    Unknown / Non-Applicable            NaN           0
# 32        NaN    NaN  Less than $1 million (USD)            NaN           0
# 34        NaN    NaN                         NaN            NaN           0
# ...       ...    ...                         ...            ...         ...
# 2220      NaN    NaN  Less than $1 million (USD)            NaN           0
# 2234      NaN    NaN          $10+ billion (USD)  AT&T, Verizon           0
# 2239      NaN    NaN                         NaN            NaN           0
# 2246      NaN    NaN                         NaN            NaN           0
# 2250      NaN    NaN                         NaN            NaN           0
#
# [352 rows x 15 columns]

# %%
# df.columns[11]
print(df['Sector'].dtype)
df['Sector'].value_counts(dropna=False)
df['Sector'] = df[df.columns[11]].replace('-1',np.nan)
df['Sector'].isnull().mean()
df[df['Sector'].isnull()]  # delay cleaning
# Out:
# object
#                                               Job Title  \
# 11                                         Data Analyst
# 21                                 Data Science Analyst
# 24                       Entry Level / Jr. Data Analyst
# 32                                         Data Analyst
# 34                                 Data Analyst (Games)
# ...                                                 ...
# 2220  MDG Functional Data Analyst-Greenwood Village, CO
# 2234   Data Analyst 3, Customer Experience - Centennial
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 11     $37K-$66K (Glassdoor est.)
# 21     $37K-$66K (Glassdoor est.)
# 24     $37K-$66K (Glassdoor est.)
# 32     $46K-$87K (Glassdoor est.)
# 34     $46K-$87K (Glassdoor est.)
# ...                           ...
# 2220  $57K-$100K (Glassdoor est.)
# 2234  $57K-$100K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 21    Job Description\r\nOur client, a music streami...     NaN
# 24    Dash Technologies is an industry leading softw...     3.8
# 32    Job Description:\r\nLegal experience is requir...     3.5
# 34    Carry1st is the leading mobile game publisher ...     NaN
# ...                                                 ...     ...
# 2220  MDG Functional Data Analyst\r\nLocation: Green...     5.0
# 2234  Business Unit: Summary Responsible for working...     3.6
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                       Company Name                         Location  \
# 11                        BulbHead                    Fairfield, NJ
# 21           MUSIC & Entertainment                     New York, NY
# 24    Dash Technologies Inc\r\n3.8                     New York, NY
# 32                   Pozent\r\n3.5                     New York, NY
# 34                        Carry1st                     New York, NY
# ...                            ...                              ...
# 2220        Georgia IT Inc.\r\n5.0  Greenwood Village, Arapahoe, CO
# 2234                Comcast\r\n3.6                    Englewood, CO
# 2239                   Amyx, Iinc.                       Aurora, CO
# 2246                      Spiceorb                       Denver, CO
# 2250                      Spiceorb                       Denver, CO
#
#             Headquarters               Size  Founded  Type of ownership  \
# 11                   NaN  1 to 50 employees      NaN  Company - Private
# 21    Marina del Rey, CA            Unknown      NaN   Company - Public
# 24          Columbus, OH  1 to 50 employees      NaN            Unknown
# 32        Piscataway, NJ  1 to 50 employees      NaN           Contract
# 34                   NaN                NaN      NaN                NaN
# ...                  ...                ...      ...                ...
# 2220      Alpharetta, GA  1 to 50 employees      NaN  Company - Private
# 2234    Philadelphia, PA   10000+ employees   1963.0   Company - Public
# 2239                 NaN                NaN      NaN                NaN
# 2246                 NaN                NaN      NaN                NaN
# 2250                 NaN                NaN      NaN                NaN
#
#      Industry Sector                     Revenue    Competitors  Easy Apply
# 11        NaN    NaN    Unknown / Non-Applicable            NaN           0
# 21        NaN    NaN    Unknown / Non-Applicable            NaN           0
# 24        NaN    NaN    Unknown / Non-Applicable            NaN           0
# 32        NaN    NaN  Less than $1 million (USD)            NaN           0
# 34        NaN    NaN                         NaN            NaN           0
# ...       ...    ...                         ...            ...         ...
# 2220      NaN    NaN  Less than $1 million (USD)            NaN           0
# 2234      NaN    NaN          $10+ billion (USD)  AT&T, Verizon           0
# 2239      NaN    NaN                         NaN            NaN           0
# 2246      NaN    NaN                         NaN            NaN           0
# 2250      NaN    NaN                         NaN            NaN           0
#
# [352 rows x 15 columns]

# %%
# df.columns[12]
print(df['Revenue'].dtype)
df['Revenue'].value_counts(dropna=False)
df['Revenue'] = df[df.columns[12]].replace('-1',np.nan)
df['Revenue'].isnull().mean()
df[df['Revenue'].isnull()]  # delay cleaning
# Out:
# object
#                                               Job Title  \
# 34                                 Data Analyst (Games)
# 55                               Data Reporting Analyst
# 68                                 Data Science Analyst
# 90                                         Data Analyst
# 109                                        Data Analyst
# ...                                                 ...
# 2200                                       Data Analyst
# 2202                             Financial Data Analyst
# 2239                       Senior Contract Data Analyst
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 34     $46K-$87K (Glassdoor est.)
# 55     $46K-$87K (Glassdoor est.)
# 68     $51K-$88K (Glassdoor est.)
# 90     $51K-$87K (Glassdoor est.)
# 109    $51K-$87K (Glassdoor est.)
# ...                           ...
# 2200   $49K-$91K (Glassdoor est.)
# 2202   $49K-$91K (Glassdoor est.)
# 2239  $78K-$104K (Glassdoor est.)
# 2246  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# 109   Data Analyst\r\n\r\nJersey City, NJ\r\n\r\n12+...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name         Location  \
# 34                                             Carry1st     New York, NY
# 55                                       NADAP NYS INC.     New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                           NYU Langone Medical Center     New York, NY
# 109                                Vertex Intel Systems  Jersey City, NJ
# ...                                                 ...              ...
# 2200          TechAspect Solutions, Inc. dba TA Digital   Centennial, CO
# 2202        Black Knight Financial Technology Solutions       Denver, CO
# 2239                                        Amyx, Iinc.       Aurora, CO
# 2246                                           Spiceorb       Denver, CO
# 2250                                           Spiceorb       Denver, CO
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 34            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 55            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 68            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 90            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 109           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# ...           ...  ...      ...               ...      ...    ...     ...
# 2200          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2202          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2239          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2246          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2250          NaN  NaN      NaN               NaN      NaN    NaN     NaN
#
#      Competitors  Easy Apply
# 34           NaN           0
# 55           NaN           0
# 68           NaN           0
# 90           NaN           0
# 109          NaN           0
# ...          ...         ...
# 2200         NaN           0
# 2202         NaN           0
# 2239         NaN           0
# 2246         NaN           0
# 2250         NaN           0
#
# [162 rows x 15 columns]

# %%
# df.columns[13]
print(df['Competitors'].dtype)
df['Competitors'].value_counts(dropna=False)
df['Competitors'] = df['Competitors'].replace('-1',np.nan)
df['Competitors'].isnull().mean()
df[df['Competitors'].isnull()]  # delay cleaning
# Out:
# object
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 3                                          Data Analyst
# 5                                          Data Analyst
# 6                          Business/Data Analyst (FP&A)
# ...                                                 ...
# 2246  Technical Business Analyst (SQL, Data analytic...
# 2247  Marketing/Communications - Data Analyst-Marketing
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 5      $37K-$66K (Glassdoor est.)
# 6      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2246  $78K-$104K (Glassdoor est.)
# 2247  $78K-$104K (Glassdoor est.)
# 2248  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 5     About Cubist\r\nCubist Systematic Strategies i...     3.9
# 6     Two Sigma is a different kind of investment ma...     4.4
# ...                                                 ...     ...
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2247  Job Description\r\nJob Title: Marketing/Commun...     4.1
# 2248  Maintains systems to protect data from unautho...     2.5
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
#
#                                    Company Name        Location  \
# 0              Vera Institute of Justice\r\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\r\n3.8    New York, NY
# 3                               Celerity\r\n4.1    New York, NY
# 5                                Point72\r\n3.9    New York, NY
# 6                              Two Sigma\r\n4.4    New York, NY
# ...                                         ...             ...
# 2246                                   Spiceorb      Denver, CO
# 2247          APN Software Services Inc.\r\n4.1  Broomfield, CO
# 2248                       Avacend, Inc.\r\n2.5      Denver, CO
# 2250                                   Spiceorb      Denver, CO
# 2251         Contingent Network Services\r\n3.1  Centennial, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees   1961.0
# 1         New York, NY        10000+ employees   1893.0
# 3           McLean, VA    201 to 500 employees   2002.0
# 5         Stamford, CT  1001 to 5000 employees   2014.0
# 6         New York, NY  1001 to 5000 employees   2001.0
# ...                ...                     ...      ...
# 2246               NaN                     NaN      NaN
# 2247        Newark, CA     51 to 200 employees      NaN
# 2248    Alpharetta, GA     51 to 200 employees      NaN
# 2250               NaN                     NaN      NaN
# 2251  West Chester, OH    201 to 500 employees   1984.0
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 3     Subsidiary or Business Segment                              IT Services
# 5                  Company - Private    Investment Banking & Asset Management
# 6                  Company - Private    Investment Banking & Asset Management
# ...                              ...                                      ...
# 2246                             NaN                                      NaN
# 2247               Company - Private             Computer Hardware & Software
# 2248               Company - Private                   Staffing & Outsourcing
# 2250                             NaN                                      NaN
# 2251               Company - Private  Enterprise Software & Network Solutions
#
#                       Sector                     Revenue Competitors  \
# 0                 Non-Profit  $100 to $500 million (USD)         NaN
# 1                Health Care      $2 to $5 billion (USD)         NaN
# 3     Information Technology   $50 to $100 million (USD)         NaN
# 5                    Finance    Unknown / Non-Applicable         NaN
# 6                    Finance    Unknown / Non-Applicable         NaN
# ...                      ...                         ...         ...
# 2246                     NaN                         NaN         NaN
# 2247  Information Technology    $25 to $50 million (USD)         NaN
# 2248       Business Services    Unknown / Non-Applicable         NaN
# 2250                     NaN                         NaN         NaN
# 2251  Information Technology    $25 to $50 million (USD)         NaN
#
#       Easy Apply
# 0              1
# 1              0
# 3              0
# 5              0
# 6              0
# ...          ...
# 2246           0
# 2247           0
# 2248           0
# 2250           0
# 2251           0
#
# [1730 rows x 15 columns]

# %%
# df.columns[14]
print(df['Easy Apply'].dtype)
df['Easy Apply'].value_counts()
df['Easy Apply'] = df['Easy Apply'].replace('-1',0)
df['Easy Apply'] = df['Easy Apply'].replace('True',1)
# Out:
# int64

# %%
# Salary Estimate 将数据变为高，低两列。变为int型
# Size列同上
