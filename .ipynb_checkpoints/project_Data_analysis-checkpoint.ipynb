# %% [markdown]
# # Introduction
# <p>The dataset is from <a href='https://www.kaggle.com/andrewmvd/data-analyst-jobs'> <span> Kaggle</span> </a>.</p>
# <p>There are three questions of interest:</p>
# <p>1.Find the best jobs by salary and company rating</p>
# <p>2.Explore skills required in job descriptions</p>
# <p>3.Predict salary based on industry, location, company revenue</p>

# %% [markdown]
# Firstly, read in the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# step 1: load and clean data

# %%
# load dataset
df = pd.read_csv('./Dataset/DataAnalyst.csv',index_col=0)

df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\r\n\r\nProvides analytical and techni...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4  ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
#
#                                 Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\r\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\r\n3.8  New York, NY  New York, NY
# 2                         Squarespace\r\n3.4  New York, NY  New York, NY
# 3                            Celerity\r\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\r\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
# 1)get columns and rows of dataset
print(df.shape)  # rows: 2253 columns: 15

# 2)check null value in columns
df.info() # not exists NaN in all columns
# Out:
# (2253, 15)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 281.6+ KB

# %%
# 3)check abnormal value in columns one by one
# df.columns[0]]
print(df['Job Title'].dtype)
df['Job Title'].value_counts() # some job title could be classified
df['Job Title'] = df['Job Title'].str.lower()
df['Job Title'].value_counts()[:50]
# Out:
# object
# data analyst                                                                        411
# senior data analyst                                                                 122
# junior data analyst                                                                  47
# data business analyst                                                                31
# data quality analyst                                                                 21
# data analyst ii                                                                      17
# data governance analyst                                                              16
# reporting data analyst                                                               16
# lead data analyst                                                                    15
# financial data analyst                                                               12
# data analyst i                                                                       11
# data analyst iii                                                                     11
# marketing data analyst                                                                9
# data warehouse analyst                                                                8
# data management analyst                                                               8
# clinical data analyst                                                                 8
# technical data analyst                                                                8
# sql data analyst                                                                      7
# data science analyst                                                                  7
# healthcare data analyst                                                               6
# data security analyst                                                                 6
# research data analyst                                                                 6
# data analyst iii (healthcare analytics)                                               5
# senior healthcare data analyst                                                        5
# ny healthcare data/reporting analyst                                                  5
# product data analyst                                                                  5
# operations data analyst                                                               5
# data analyst intern                                                                   4
# senior contract data analyst                                                          4
# senior data quality analyst                                                           4
# tx healthcare data/reporting analyst                                                  4
# data analyst, data & analytics (advanced analytics) manager (multiple positions)      4
# business/data analyst                                                                 4
# data warehouse analyst iii                                                            4
# master data analyst                                                                   4
# data base programmer/analyst                                                          4
# big data analyst                                                                      4
# healthcare data/reporting analyst                                                     4
# data analyst iv                                                                       3
# data collection analyst                                                               3
# radar telemetry data analyst                                                          3
# sr. data governance analyst                                                           3
# data and reporting analyst                                                            3
# data visualization analyst                                                            3
# data analyst- remote                                                                  3
# data systems analyst                                                                  3
# hr data analyst ii                                                                    3
# division data and financial analyst                                                   3
# pricing data analyst                                                                  3
# data integrity analyst                                                                3
# Name: Job Title, dtype: int64

# %%
df = df.replace('sr. data analyst','senior data analyst')
df = df.replace('sr data analyst','senior data analyst')
df = df.replace('data analyst junior','junior data analyst')  
df = df.replace('quality data analyst','data quality analyst')
df = df.replace('business data analyst','data business analyst')
df = df.replace('data reporting analyst','reporting data analyst')
df['Job Title'].value_counts()[:50]
# Out:
# data analyst                                                                        411
# senior data analyst                                                                 122
# junior data analyst                                                                  47
# data business analyst                                                                31
# data quality analyst                                                                 21
# data analyst ii                                                                      17
# data governance analyst                                                              16
# reporting data analyst                                                               16
# lead data analyst                                                                    15
# financial data analyst                                                               12
# data analyst i                                                                       11
# data analyst iii                                                                     11
# marketing data analyst                                                                9
# data warehouse analyst                                                                8
# data management analyst                                                               8
# clinical data analyst                                                                 8
# technical data analyst                                                                8
# sql data analyst                                                                      7
# data science analyst                                                                  7
# healthcare data analyst                                                               6
# data security analyst                                                                 6
# research data analyst                                                                 6
# data analyst iii (healthcare analytics)                                               5
# senior healthcare data analyst                                                        5
# ny healthcare data/reporting analyst                                                  5
# product data analyst                                                                  5
# operations data analyst                                                               5
# data analyst intern                                                                   4
# senior contract data analyst                                                          4
# senior data quality analyst                                                           4
# tx healthcare data/reporting analyst                                                  4
# data analyst, data & analytics (advanced analytics) manager (multiple positions)      4
# business/data analyst                                                                 4
# data warehouse analyst iii                                                            4
# master data analyst                                                                   4
# data base programmer/analyst                                                          4
# big data analyst                                                                      4
# healthcare data/reporting analyst                                                     4
# data analyst iv                                                                       3
# data collection analyst                                                               3
# radar telemetry data analyst                                                          3
# sr. data governance analyst                                                           3
# data and reporting analyst                                                            3
# data visualization analyst                                                            3
# data analyst- remote                                                                  3
# data systems analyst                                                                  3
# hr data analyst ii                                                                    3
# division data and financial analyst                                                   3
# pricing data analyst                                                                  3
# data integrity analyst                                                                3
# Name: Job Title, dtype: int64

# %%
# df.columns[1]
print(df['Salary Estimate'].dtype)
df['Salary Estimate'].unique() # need to repace -1 into np.nan
df['Salary Estimate'] = df['Salary Estimate'].replace('-1',np.nan)
df['Salary Estimate'].value_counts(dropna=False)
df['Salary Estimate'].isnull().mean() * 100 # only exists 1 missing value, so I decide to drop this data
df[df['Salary Estimate'].isnull()]
df.drop(index=2149,inplace=True)
# Out:
# object

# %%
# split salary estimate into lower 
s = df["Salary Estimate"].str.split(" ",n=1,expand=True)
sr = s[0].str.split('-',expand=True,n=1)
df['lower_salary'] = sr[0].str.replace('$','')
df['lower_salary'] = df['lower_salary'].str.replace('K','000')
df['upper_salary'] = sr[1].str.replace('$','')
df['upper_salary'] = df['upper_salary'].str.replace('K','000')

# convert data type
df['upper_salary'] = df['upper_salary'].astype('int')
df['lower_salary'] = df['lower_salary'].astype('int')

# add new column 'average_salary'
df['average_salary'] = (df['upper_salary'] + df['lower_salary']) / 2

# delete column
df = df.drop(columns=['Salary Estimate', 'upper_salary', 'lower_salary'])

# %%
# df.columns[2]
print(df['Job Description'].dtype)
df['Job Description'].value_counts(dropna=False)
df['Job Description'].isnull().mean()   # no missing values
# Out:
# object
# 0.0

# %%
# df.columns[3]
print(df['Rating'].dtype)
df['Rating'].unique()
df['Rating'] = df['Rating'].replace(-1,np.nan)
print(df['Rating'].isnull().mean())
df['Rating'].value_counts(dropna=False)
df[df['Rating'].isnull()]  # delay cleaning
# Out:
# float64
# 0.12285581826611033
#                          Job Title  \
# 11                    data analyst
# 21            data science analyst
# 34                    data analyst
# 36           data business analyst
# 40                business analyst
# ...                            ...
# 2200                  data analyst
# 2202        financial data analyst
# 2239  senior contract data analyst
# 2246   technical business analyst
# 2250   technical business analyst
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 21    Job Description\r\nOur client, a music streami...     NaN
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 36    At Clear Street, we are disrupting the institu...     NaN
# 40    Company Description\r\n\r\nPinto is building t...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                      Company Name        Location  \
# 11                                       BulbHead   Fairfield, NJ
# 21                          MUSIC & Entertainment    New York, NY
# 34                                       Carry1st    New York, NY
# 36                                   Clear Street    New York, NY
# 40                                          Pinto    New York, NY
# ...                                           ...             ...
# 2200    TechAspect Solutions, Inc. dba TA Digital  Centennial, CO
# 2202  Black Knight Financial Technology Solutions      Denver, CO
# 2239                                  Amyx, Iinc.      Aurora, CO
# 2246                                     Spiceorb      Denver, CO
# 2250                                     Spiceorb      Denver, CO
#
#             Headquarters                 Size  Founded  Type of ownership  \
# 11                    -1    1 to 50 employees       -1  Company - Private
# 21    Marina del Rey, CA              Unknown       -1   Company - Public
# 34                    -1                   -1       -1                 -1
# 36          New York, NY  51 to 200 employees     2018   Company - Public
# 40          New York, NY    1 to 50 employees       -1  Company - Private
# ...                  ...                  ...      ...                ...
# 2200                  -1                   -1       -1                 -1
# 2202                  -1                   -1       -1                 -1
# 2239                  -1                   -1       -1                 -1
# 2246                  -1                   -1       -1                 -1
# 2250                  -1                   -1       -1                 -1
#
#      Industry Sector                   Revenue Competitors Easy Apply  \
# 11         -1     -1  Unknown / Non-Applicable          -1         -1
# 21         -1     -1  Unknown / Non-Applicable          -1         -1
# 34         -1     -1                        -1          -1         -1
# 36         -1     -1    $1 to $5 million (USD)          -1         -1
# 40         -1     -1  Unknown / Non-Applicable          -1         -1
# ...       ...    ...                       ...         ...        ...
# 2200       -1     -1                        -1          -1         -1
# 2202       -1     -1                        -1          -1         -1
# 2239       -1     -1                        -1          -1         -1
# 2246       -1     -1                        -1          -1         -1
# 2250       -1     -1                        -1          -1         -1
#
#       average_salary
# 11           51500.0
# 21           51500.0
# 34           66500.0
# 36           66500.0
# 40           66500.0
# ...              ...
# 2200         70000.0
# 2202         70000.0
# 2239         91000.0
# 2246         91000.0
# 2250         91000.0
#
# [265 rows x 15 columns]

# %%
# df.columns[4]
print(df['Company Name'].dtype)
df['Company Name'].unique()
df['Company Name'].str.split('\r\n',n=1,expand=True)
df['Company Name'] = df['Company Name'].str.split('\r\n',n=1,expand=True)[0]
print(df['Company Name'].isnull().mean())
df[df['Company Name'].isnull()]
df.drop(index=1860,inplace=True)
# Out:
# object
# 0.0004636068613815484

# %%
# df.columns[5]
print(df['Location'].dtype)
df['Location'].value_counts(dropna=False)
print(df['Location'].isnull().mean())
# Out:
# object
# 0.0

# %%
# df.columns[6]
print(df['Headquarters'].dtype)
df['Headquarters'].unique()
df['Headquarters'].value_counts(dropna=False)
df['Headquarters'] = df['Headquarters'].replace('-1',np.nan)
print(df['Headquarters'].isnull().mean())
df[df['Headquarters'].isnull()] # delay cleaning
# Out:
# object
# 0.0774582560296846
#                          Job Title  \
# 11                    data analyst
# 34                    data analyst
# 55          data reporting analyst
# 68            data science analyst
# 90                    data analyst
# ...                            ...
# 2200                  data analyst
# 2202        financial data analyst
# 2239  senior contract data analyst
# 2246   technical business analyst
# 2250   technical business analyst
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name        Location  \
# 11                                             BulbHead   Fairfield, NJ
# 34                                             Carry1st    New York, NY
# 55                                       NADAP NYS INC.    New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)    New York, NY
# 90                           NYU Langone Medical Center    New York, NY
# ...                                                 ...             ...
# 2200          TechAspect Solutions, Inc. dba TA Digital  Centennial, CO
# 2202        Black Knight Financial Technology Solutions      Denver, CO
# 2239                                        Amyx, Iinc.      Aurora, CO
# 2246                                           Spiceorb      Denver, CO
# 2250                                           Spiceorb      Denver, CO
#
#      Headquarters               Size  Founded  Type of ownership Industry  \
# 11            NaN  1 to 50 employees       -1  Company - Private       -1
# 34            NaN                 -1       -1                 -1       -1
# 55            NaN                 -1       -1                 -1       -1
# 68            NaN                 -1       -1                 -1       -1
# 90            NaN                 -1       -1                 -1       -1
# ...           ...                ...      ...                ...      ...
# 2200          NaN                 -1       -1                 -1       -1
# 2202          NaN                 -1       -1                 -1       -1
# 2239          NaN                 -1       -1                 -1       -1
# 2246          NaN                 -1       -1                 -1       -1
# 2250          NaN                 -1       -1                 -1       -1
#
#      Sector                   Revenue Competitors Easy Apply  average_salary
# 11       -1  Unknown / Non-Applicable          -1         -1         51500.0
# 34       -1                        -1          -1         -1         66500.0
# 55       -1                        -1          -1         -1         66500.0
# 68       -1                        -1          -1         -1         69500.0
# 90       -1                        -1          -1         -1         69000.0
# ...     ...                       ...         ...        ...             ...
# 2200     -1                        -1          -1         -1         70000.0
# 2202     -1                        -1          -1         -1         70000.0
# 2239     -1                        -1          -1         -1         91000.0
# 2246     -1                        -1          -1         -1         91000.0
# 2250     -1                        -1          -1         -1         91000.0
#
# [167 rows x 15 columns]

# %%
# df.columns[7]
print(df['Size'].dtype)
df['Size'].unique()
df['Size'] = df['Size'].replace('-1',np.nan)
print(df['Size'].isnull().mean())
df[df['Size'].isnull()] # delay cleaning
# Out:
# object
# 0.07328385899814471
#                          Job Title  \
# 34                    data analyst
# 55          data reporting analyst
# 68            data science analyst
# 90                    data analyst
# 109                   data analyst
# ...                            ...
# 2200                  data analyst
# 2202        financial data analyst
# 2239  senior contract data analyst
# 2246   technical business analyst
# 2250   technical business analyst
#
#                                         Job Description  Rating  \
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# 109   Data Analyst\r\n\r\nJersey City, NJ\r\n\r\n12+...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name         Location  \
# 34                                             Carry1st     New York, NY
# 55                                       NADAP NYS INC.     New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                           NYU Langone Medical Center     New York, NY
# 109                                Vertex Intel Systems  Jersey City, NJ
# ...                                                 ...              ...
# 2200          TechAspect Solutions, Inc. dba TA Digital   Centennial, CO
# 2202        Black Knight Financial Technology Solutions       Denver, CO
# 2239                                        Amyx, Iinc.       Aurora, CO
# 2246                                           Spiceorb       Denver, CO
# 2250                                           Spiceorb       Denver, CO
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 34            NaN  NaN       -1                -1       -1     -1      -1
# 55            NaN  NaN       -1                -1       -1     -1      -1
# 68            NaN  NaN       -1                -1       -1     -1      -1
# 90            NaN  NaN       -1                -1       -1     -1      -1
# 109           NaN  NaN       -1                -1       -1     -1      -1
# ...           ...  ...      ...               ...      ...    ...     ...
# 2200          NaN  NaN       -1                -1       -1     -1      -1
# 2202          NaN  NaN       -1                -1       -1     -1      -1
# 2239          NaN  NaN       -1                -1       -1     -1      -1
# 2246          NaN  NaN       -1                -1       -1     -1      -1
# 2250          NaN  NaN       -1                -1       -1     -1      -1
#
#      Competitors Easy Apply  average_salary
# 34            -1         -1         66500.0
# 55            -1         -1         66500.0
# 68            -1         -1         69500.0
# 90            -1         -1         69000.0
# 109           -1         -1         69000.0
# ...          ...        ...             ...
# 2200          -1         -1         70000.0
# 2202          -1         -1         70000.0
# 2239          -1         -1         91000.0
# 2246          -1         -1         91000.0
# 2250          -1         -1         91000.0
#
# [158 rows x 15 columns]

# %%
# df.columns[8]
print(df['Founded'].dtype)
df['Founded'].unique()
df['Founded'] = df['Founded'].replace(-1,np.nan)
df['Founded'].value_counts(dropna=False)
print(df['Founded'].isnull().mean())
df[df['Founded'].isnull()] # delay cleaning
# Out:
# int64
# 0.29545454545454547
#                            Job Title  \
# 11                      data analyst
# 15       sustainability data analyst
# 21              data science analyst
# 23                      data analyst
# 24    entry level / jr. data analyst
# ...                              ...
# 2239    senior contract data analyst
# 2241        data security analyst fr
# 2244           data security analyst
# 2246     technical business analyst
# 2250     technical business analyst
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 15    Job Description\r\nRole Description\r\n\r\nSus...     3.6
# 21    Job Description\r\nOur client, a music streami...     NaN
# 23    Haven Life is an insurtech innovator at MassMu...     3.5
# 24    Dash Technologies is an industry leading softw...     3.8
# ...                                                 ...     ...
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2241  Maintains systems to protect data from unautho...     2.5
# 2244  Contract Duration: 9 Months\r\n\r\nLocation: D...     2.5
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                Company Name       Location        Headquarters  \
# 11                 BulbHead  Fairfield, NJ                 NaN
# 15      CodeGreen Solutions   New York, NY        New York, NY
# 21    MUSIC & Entertainment   New York, NY  Marina del Rey, CA
# 23                  Andiamo   New York, NY          Warren, MI
# 24    Dash Technologies Inc   New York, NY        Columbus, OH
# ...                     ...            ...                 ...
# 2239            Amyx, Iinc.     Aurora, CO                 NaN
# 2241          Avacend, Inc.     Denver, CO      Alpharetta, GA
# 2244          Avacend, Inc.     Denver, CO      Alpharetta, GA
# 2246               Spiceorb     Denver, CO                 NaN
# 2250               Spiceorb     Denver, CO                 NaN
#
#                       Size  Founded  Type of ownership  \
# 11       1 to 50 employees      NaN  Company - Private
# 15       1 to 50 employees      NaN  Company - Private
# 21                 Unknown      NaN   Company - Public
# 23    201 to 500 employees      NaN  Company - Private
# 24       1 to 50 employees      NaN            Unknown
# ...                    ...      ...                ...
# 2239                   NaN      NaN                 -1
# 2241   51 to 200 employees      NaN  Company - Private
# 2244   51 to 200 employees      NaN  Company - Private
# 2246                   NaN      NaN                 -1
# 2250                   NaN      NaN                 -1
#
#                            Industry                             Sector  \
# 11                               -1                                 -1
# 15    Building & Personnel Services                  Business Services
# 21                               -1                                 -1
# 23               Casual Restaurants  Restaurants, Bars & Food Services
# 24                               -1                                 -1
# ...                             ...                                ...
# 2239                             -1                                 -1
# 2241         Staffing & Outsourcing                  Business Services
# 2244         Staffing & Outsourcing                  Business Services
# 2246                             -1                                 -1
# 2250                             -1                                 -1
#
#                        Revenue Competitors Easy Apply  average_salary
# 11    Unknown / Non-Applicable          -1         -1         51500.0
# 15    Unknown / Non-Applicable          -1         -1         51500.0
# 21    Unknown / Non-Applicable          -1         -1         51500.0
# 23      $1 to $5 million (USD)          -1         -1         51500.0
# 24    Unknown / Non-Applicable          -1         -1         51500.0
# ...                        ...         ...        ...             ...
# 2239                        -1          -1         -1         91000.0
# 2241  Unknown / Non-Applicable          -1         -1         91000.0
# 2244  Unknown / Non-Applicable          -1         -1         91000.0
# 2246                        -1          -1         -1         91000.0
# 2250                        -1          -1         -1         91000.0
#
# [637 rows x 15 columns]

# %%
# df.columns[9]
print(df['Type of ownership'].dtype)
df['Type of ownership'].unique()
df['Type of ownership'] = df['Type of ownership'].replace('-1',np.nan)
print(df['Type of ownership'].isnull().mean())
df[df['Type of ownership'].isnull()] # delay cleaning
# Out:
# object
# 0.07328385899814471
#                          Job Title  \
# 34                    data analyst
# 55          data reporting analyst
# 68            data science analyst
# 90                    data analyst
# 109                   data analyst
# ...                            ...
# 2200                  data analyst
# 2202        financial data analyst
# 2239  senior contract data analyst
# 2246   technical business analyst
# 2250   technical business analyst
#
#                                         Job Description  Rating  \
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# 109   Data Analyst\r\n\r\nJersey City, NJ\r\n\r\n12+...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name         Location  \
# 34                                             Carry1st     New York, NY
# 55                                       NADAP NYS INC.     New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                           NYU Langone Medical Center     New York, NY
# 109                                Vertex Intel Systems  Jersey City, NJ
# ...                                                 ...              ...
# 2200          TechAspect Solutions, Inc. dba TA Digital   Centennial, CO
# 2202        Black Knight Financial Technology Solutions       Denver, CO
# 2239                                        Amyx, Iinc.       Aurora, CO
# 2246                                           Spiceorb       Denver, CO
# 2250                                           Spiceorb       Denver, CO
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 34            NaN  NaN      NaN               NaN       -1     -1      -1
# 55            NaN  NaN      NaN               NaN       -1     -1      -1
# 68            NaN  NaN      NaN               NaN       -1     -1      -1
# 90            NaN  NaN      NaN               NaN       -1     -1      -1
# 109           NaN  NaN      NaN               NaN       -1     -1      -1
# ...           ...  ...      ...               ...      ...    ...     ...
# 2200          NaN  NaN      NaN               NaN       -1     -1      -1
# 2202          NaN  NaN      NaN               NaN       -1     -1      -1
# 2239          NaN  NaN      NaN               NaN       -1     -1      -1
# 2246          NaN  NaN      NaN               NaN       -1     -1      -1
# 2250          NaN  NaN      NaN               NaN       -1     -1      -1
#
#      Competitors Easy Apply  average_salary
# 34            -1         -1         66500.0
# 55            -1         -1         66500.0
# 68            -1         -1         69500.0
# 90            -1         -1         69000.0
# 109           -1         -1         69000.0
# ...          ...        ...             ...
# 2200          -1         -1         70000.0
# 2202          -1         -1         70000.0
# 2239          -1         -1         91000.0
# 2246          -1         -1         91000.0
# 2250          -1         -1         91000.0
#
# [158 rows x 15 columns]

# %%
# df.columns[10]
print(df['Industry'].dtype)
df['Industry'].unique()
df['Industry'] = df['Industry'].replace('-1',np.nan)
print(df['Industry'].isnull().mean())
df[df['Industry'].isnull()]  # delay cleaning
# Out:
# object
# 0.16001855287569575
#                            Job Title  \
# 11                      data analyst
# 21              data science analyst
# 24    entry level / jr. data analyst
# 32                      data analyst
# 34                      data analyst
# ...                              ...
# 2220     mdg functional data analyst
# 2234                  data analyst 3
# 2239    senior contract data analyst
# 2246     technical business analyst
# 2250     technical business analyst
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 21    Job Description\r\nOur client, a music streami...     NaN
# 24    Dash Technologies is an industry leading softw...     3.8
# 32    Job Description:\r\nLegal experience is requir...     3.5
# 34    Carry1st is the leading mobile game publisher ...     NaN
# ...                                                 ...     ...
# 2220  MDG Functional Data Analyst\r\nLocation: Green...     5.0
# 2234  Business Unit: Summary Responsible for working...     3.6
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                Company Name                         Location  \
# 11                 BulbHead                    Fairfield, NJ
# 21    MUSIC & Entertainment                     New York, NY
# 24    Dash Technologies Inc                     New York, NY
# 32                   Pozent                     New York, NY
# 34                 Carry1st                     New York, NY
# ...                     ...                              ...
# 2220        Georgia IT Inc.  Greenwood Village, Arapahoe, CO
# 2234                Comcast                    Englewood, CO
# 2239            Amyx, Iinc.                       Aurora, CO
# 2246               Spiceorb                       Denver, CO
# 2250               Spiceorb                       Denver, CO
#
#             Headquarters               Size  Founded  Type of ownership  \
# 11                   NaN  1 to 50 employees      NaN  Company - Private
# 21    Marina del Rey, CA            Unknown      NaN   Company - Public
# 24          Columbus, OH  1 to 50 employees      NaN            Unknown
# 32        Piscataway, NJ  1 to 50 employees      NaN           Contract
# 34                   NaN                NaN      NaN                NaN
# ...                  ...                ...      ...                ...
# 2220      Alpharetta, GA  1 to 50 employees      NaN  Company - Private
# 2234    Philadelphia, PA   10000+ employees   1963.0   Company - Public
# 2239                 NaN                NaN      NaN                NaN
# 2246                 NaN                NaN      NaN                NaN
# 2250                 NaN                NaN      NaN                NaN
#
#      Industry Sector                     Revenue    Competitors Easy Apply  \
# 11        NaN     -1    Unknown / Non-Applicable             -1         -1
# 21        NaN     -1    Unknown / Non-Applicable             -1         -1
# 24        NaN     -1    Unknown / Non-Applicable             -1         -1
# 32        NaN     -1  Less than $1 million (USD)             -1         -1
# 34        NaN     -1                          -1             -1         -1
# ...       ...    ...                         ...            ...        ...
# 2220      NaN     -1  Less than $1 million (USD)             -1         -1
# 2234      NaN     -1          $10+ billion (USD)  AT&T, Verizon         -1
# 2239      NaN     -1                          -1             -1         -1
# 2246      NaN     -1                          -1             -1         -1
# 2250      NaN     -1                          -1             -1         -1
#
#       average_salary
# 11           51500.0
# 21           51500.0
# 24           51500.0
# 32           66500.0
# 34           66500.0
# ...              ...
# 2220         78500.0
# 2234         78500.0
# 2239         91000.0
# 2246         91000.0
# 2250         91000.0
#
# [345 rows x 15 columns]

# %%
# df.columns[11]
print(df['Sector'].dtype)
df['Sector'].unique()
df['Sector'] = df['Sector'].replace('-1',np.nan)
print(df['Sector'].isnull().mean())
df[df['Sector'].isnull()]  # delay cleaning
# Out:
# object
# 0.16001855287569575
#                            Job Title  \
# 11                      data analyst
# 21              data science analyst
# 24    entry level / jr. data analyst
# 32                      data analyst
# 34                      data analyst
# ...                              ...
# 2220     mdg functional data analyst
# 2234                  data analyst 3
# 2239    senior contract data analyst
# 2246     technical business analyst
# 2250     technical business analyst
#
#                                         Job Description  Rating  \
# 11    BulbHead is currently seeking a Data Analyst t...     NaN
# 21    Job Description\r\nOur client, a music streami...     NaN
# 24    Dash Technologies is an industry leading softw...     3.8
# 32    Job Description:\r\nLegal experience is requir...     3.5
# 34    Carry1st is the leading mobile game publisher ...     NaN
# ...                                                 ...     ...
# 2220  MDG Functional Data Analyst\r\nLocation: Green...     5.0
# 2234  Business Unit: Summary Responsible for working...     3.6
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                Company Name                         Location  \
# 11                 BulbHead                    Fairfield, NJ
# 21    MUSIC & Entertainment                     New York, NY
# 24    Dash Technologies Inc                     New York, NY
# 32                   Pozent                     New York, NY
# 34                 Carry1st                     New York, NY
# ...                     ...                              ...
# 2220        Georgia IT Inc.  Greenwood Village, Arapahoe, CO
# 2234                Comcast                    Englewood, CO
# 2239            Amyx, Iinc.                       Aurora, CO
# 2246               Spiceorb                       Denver, CO
# 2250               Spiceorb                       Denver, CO
#
#             Headquarters               Size  Founded  Type of ownership  \
# 11                   NaN  1 to 50 employees      NaN  Company - Private
# 21    Marina del Rey, CA            Unknown      NaN   Company - Public
# 24          Columbus, OH  1 to 50 employees      NaN            Unknown
# 32        Piscataway, NJ  1 to 50 employees      NaN           Contract
# 34                   NaN                NaN      NaN                NaN
# ...                  ...                ...      ...                ...
# 2220      Alpharetta, GA  1 to 50 employees      NaN  Company - Private
# 2234    Philadelphia, PA   10000+ employees   1963.0   Company - Public
# 2239                 NaN                NaN      NaN                NaN
# 2246                 NaN                NaN      NaN                NaN
# 2250                 NaN                NaN      NaN                NaN
#
#      Industry Sector                     Revenue    Competitors Easy Apply  \
# 11        NaN    NaN    Unknown / Non-Applicable             -1         -1
# 21        NaN    NaN    Unknown / Non-Applicable             -1         -1
# 24        NaN    NaN    Unknown / Non-Applicable             -1         -1
# 32        NaN    NaN  Less than $1 million (USD)             -1         -1
# 34        NaN    NaN                          -1             -1         -1
# ...       ...    ...                         ...            ...        ...
# 2220      NaN    NaN  Less than $1 million (USD)             -1         -1
# 2234      NaN    NaN          $10+ billion (USD)  AT&T, Verizon         -1
# 2239      NaN    NaN                          -1             -1         -1
# 2246      NaN    NaN                          -1             -1         -1
# 2250      NaN    NaN                          -1             -1         -1
#
#       average_salary
# 11           51500.0
# 21           51500.0
# 24           51500.0
# 32           66500.0
# 34           66500.0
# ...              ...
# 2220         78500.0
# 2234         78500.0
# 2239         91000.0
# 2246         91000.0
# 2250         91000.0
#
# [345 rows x 15 columns]

# %%
# df.columns[12]
print(df['Revenue'].dtype)
df['Revenue'].unique()
df['Revenue'] = df['Revenue'].replace('-1',np.nan)
print(df['Revenue'].isnull().mean())
df[df['Revenue'].isnull()]  # delay cleaning
# Out:
# object
# 0.07328385899814471
#                          Job Title  \
# 34                    data analyst
# 55          data reporting analyst
# 68            data science analyst
# 90                    data analyst
# 109                   data analyst
# ...                            ...
# 2200                  data analyst
# 2202        financial data analyst
# 2239  senior contract data analyst
# 2246   technical business analyst
# 2250   technical business analyst
#
#                                         Job Description  Rating  \
# 34    Carry1st is the leading mobile game publisher ...     NaN
# 55    OverviewThe Data Analyst is a new position in ...     NaN
# 68    Job Details\r\n\r\nLevel\r\n\r\nExperienced\r\...     NaN
# 90    NYU Grossman School of Medicine is one of the ...     NaN
# 109   Data Analyst\r\n\r\nJersey City, NJ\r\n\r\n12+...     NaN
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                            Company Name         Location  \
# 34                                             Carry1st     New York, NY
# 55                                       NADAP NYS INC.     New York, NY
# 68    Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                           NYU Langone Medical Center     New York, NY
# 109                                Vertex Intel Systems  Jersey City, NJ
# ...                                                 ...              ...
# 2200          TechAspect Solutions, Inc. dba TA Digital   Centennial, CO
# 2202        Black Knight Financial Technology Solutions       Denver, CO
# 2239                                        Amyx, Iinc.       Aurora, CO
# 2246                                           Spiceorb       Denver, CO
# 2250                                           Spiceorb       Denver, CO
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 34            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 55            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 68            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 90            NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 109           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# ...           ...  ...      ...               ...      ...    ...     ...
# 2200          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2202          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2239          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2246          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2250          NaN  NaN      NaN               NaN      NaN    NaN     NaN
#
#      Competitors Easy Apply  average_salary
# 34            -1         -1         66500.0
# 55            -1         -1         66500.0
# 68            -1         -1         69500.0
# 90            -1         -1         69000.0
# 109           -1         -1         69000.0
# ...          ...        ...             ...
# 2200          -1         -1         70000.0
# 2202          -1         -1         70000.0
# 2239          -1         -1         91000.0
# 2246          -1         -1         91000.0
# 2250          -1         -1         91000.0
#
# [158 rows x 15 columns]

# %%
# df.columns[13]
print(df['Competitors'].dtype)
df['Competitors'].unique()
df['Competitors'] = df['Competitors'].replace('-1',np.nan)
print(df['Competitors'].isnull().mean())
df[df['Competitors'].isnull()]  # the missing value is too much, so I decide to delete this column
df = df.drop(columns = ['Competitors'])
# Out:
# object
# 0.7690166975881262

# %%
# df.columns[14]
print(df['Easy Apply'].dtype)
df['Easy Apply'].value_counts()
df['Easy Apply'] = df['Easy Apply'].replace('True',1)
# Out:
# object

# %%
# Now, the missing values for all columns
print(df.isnull().mean().sort_values() * 100)
# Out:
# Job Title             0.000000
# Job Description       0.000000
# Company Name          0.000000
# Location              0.000000
# Easy Apply            0.000000
# average_salary        0.000000
# Size                  7.328386
# Type of ownership     7.328386
# Revenue               7.328386
# Headquarters          7.745826
# Rating               12.244898
# Industry             16.001855
# Sector               16.001855
# Founded              29.545455
# dtype: float64

# %%
df.corr()
# Out:
#                   Rating   Founded  average_salary
# Rating          1.000000  0.179638        0.047219
# Founded         0.179638  1.000000        0.093385
# average_salary  0.047219  0.093385        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2156 entries, 0 to 2252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2156 non-null   object
#  1   Job Description    2156 non-null   object
#  2   Rating             1892 non-null   float64
#  3   Company Name       2156 non-null   object
#  4   Location           2156 non-null   object
#  5   Headquarters       1989 non-null   object
#  6   Size               1998 non-null   object
#  7   Founded            1519 non-null   float64
#  8   Type of ownership  1998 non-null   object
#  9   Industry           1811 non-null   object
#  10  Sector             1811 non-null   object
#  11  Revenue            1998 non-null   object
#  12  Easy Apply         2156 non-null   object
#  13  average_salary     2156 non-null   float64
# dtypes: float64(3), object(11)
# memory usage: 252.7+ KB

# %% [markdown]
# 1.Find the best jobs by salary and company rating

# %%
df.groupby('Job Title').size().sort_values(ascending=False)[:10]
# Out:
# Job Title
# data analyst               595
# senior data analyst        202
# junior data analyst         62
# business data analyst       28
# data quality analyst        19
# lead data analyst           19
# data governance analyst     16
# data reporting analyst      14
# data analyst iii            13
# financial data analyst      13
# dtype: int64

# %% [markdown]
# 2.Explore skills required in job descriptions

# %% [markdown]
# 3.Predict salary based on industry, location, company revenue
